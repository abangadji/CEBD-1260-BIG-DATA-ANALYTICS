# %% [markdown]
# # Apriori Examples

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# ## Numerical example from the mlxtend website
# https://rasbt.github.io/mlxtend/user_guide/preprocessing/TransactionEncoder/

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
model = TransactionEncoder()
encoded_results = model.fit(dataset).transform(dataset)
df = pd.DataFrame(encoded_results, columns=model.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
apriori(df, min_support=0.6)
# Out:
#     support   itemsets
# 0       0.8        [3]
# 1       1.0        [5]
# 2       0.6        [6]
# 3       0.6        [8]
# 4       0.6       [10]
# 5       0.8     [3, 5]
# 6       0.6     [3, 8]
# 7       0.6     [5, 6]
# 8       0.6     [5, 8]
# 9       0.6    [5, 10]
# 10      0.6  [3, 5, 8]

# %%
apriori(df, min_support=0.6, use_colnames=True)
# Out:
#     support                     itemsets
# 0       0.8                       [Eggs]
# 1       1.0               [Kidney Beans]
# 2       0.6                       [Milk]
# 3       0.6                      [Onion]
# 4       0.6                     [Yogurt]
# 5       0.8         [Eggs, Kidney Beans]
# 6       0.6                [Eggs, Onion]
# 7       0.6         [Kidney Beans, Milk]
# 8       0.6        [Kidney Beans, Onion]
# 9       0.6       [Kidney Beans, Yogurt]
# 10      0.6  [Eggs, Kidney Beans, Onion]

# %% [markdown]
# ## Online Retail
# http://archive.ics.uci.edu/ml/datasets/online+retail

# %%
df = pd.read_csv('online_retail.csv')
df = df.pivot_table(index='InvoiceNo', columns='Description', values='Quantity', aggfunc=len).fillna(0.0)

# %%
apriori(df, min_support=0.02, use_colnames=True).sort_values('support', ascending=False)
# Out:
#        support                                           itemsets
# 103   0.122704                                            [ Eggs]
# 109   0.119030                                     [ White Bread]
# 97    0.109478                                      [ 2pct. Milk]
# 10    0.097722                                    [ Potato Chips]
# 3     0.093314                       [ 98pct. Fat Free Hamburger]
# 86    0.092579                                        [ Hot Dogs]
# 181   0.085231                                    [ Sweet Relish]
# 5     0.080088                                          [ Onions]
# 134   0.079353                                      [ Toothpaste]
# 117   0.077884                                            [ Cola]
# 176   0.077149                                     [ Wheat Bread]
# 192   0.074210                                    [ Toilet Paper]
# 152   0.071271                                  [ Hamburger Buns]
# 81    0.069067                        [ Pepperoni Pizza - Frozen]
# 162   0.067597                                   [ Domestic Beer]
# 100   0.066128                                        [ Tomatoes]
# 96    0.064658                                         [ Bologna]
# 98    0.063924                                    [ Popcorn Salt]
# 157   0.062454                                   [ Ramen Noodles]
# 91    0.060985                                         [ Raisins]
# 126   0.059515                                         [ Bananas]
# 129   0.058780                                    [ Hot Dog Buns]
# 154   0.058780                                    [ French Fries]
# 0     0.058780                                [ Hair Conditioner]
# 94    0.057311                                     [ Pancake Mix]
# 166   0.057311                                          [ Garlic]
# 67    0.056576                                    [ Orange Juice]
# 88    0.055841                                   [ Frozen Shrimp]
# 132   0.055841                                         [ Oranges]
# 59    0.055841                                           [ Plums]
# ...        ...                                                ...
# 422   0.020573                       [ Brown Sugar,  White Bread]
# 420   0.020573                        [ Sour Cream,  Wheat Bread]
# 418   0.020573                               [ Sour Cream,  Cola]
# 923   0.020573         [ 2pct. Milk,  White Bread,  Hot Dog Buns]
# 884   0.020573                 [ Pancake Mix,  2pct. Milk,  Eggs]
# 879   0.020573          [ Hot Dogs,  Sweet Relish,  Toilet Paper]
# 823   0.020573             [ Potato Chips,  Eggs,  Domestic Beer]
# 497   0.020573                          [ Bologna,  Popcorn Salt]
# 564   0.020573                         [ Tomatoes,  French Fries]
# 826   0.020573              [ Potato Chips,  Eggs,  Toilet Paper]
# 828   0.020573             [ Potato Chips,  White Bread,  Apples]
# 829   0.020573            [ Potato Chips,  White Bread,  Bananas]
# 553   0.020573                     [ Popcorn Salt,  French Fries]
# 552   0.020573                      [ Popcorn Salt,  Canned Tuna]
# 550   0.020573                 [ Popcorn Salt,  C Cell Batteries]
# 838   0.020573                [ Potato Chips,  Cola,  Toothpaste]
# 540   0.020573               [ 2pct. Milk,  Creamy Peanut Butter]
# 842   0.020573            [ Salsa Dip,  2pct. Milk,  White Bread]
# 538   0.020573                         [ 2pct. Milk,  Paper Cups]
# 530   0.020573                       [ 2pct. Milk,  Garlic Bread]
# 851   0.020573  [ Pepperoni Pizza - Frozen,  2pct. Milk,  Toot...
# 853   0.020573  [ Pepperoni Pizza - Frozen,  2pct. Milk,  Whea...
# 526   0.020573                  [ 2pct. Milk,  Microwave Popcorn]
# 855   0.020573          [ Pepperoni Pizza - Frozen,  Eggs,  Cola]
# 856   0.020573  [ Pepperoni Pizza - Frozen,  Eggs,  Domestic B...
# 517   0.020573               [ 2pct. Milk,  Sharp Cheddar Cheese]
# 859   0.020573                    [ Hot Dogs,  2pct. Milk,  Cola]
# 861   0.020573             [ Hot Dogs,  2pct. Milk,  Wheat Bread]
# 714   0.020573     [ Hair Conditioner,  White Bread,  Toothpaste]
# 1030  0.020573  [ Eggs,  White Bread,  Toothpaste,  Sweet Relish]
#
# [1031 rows x 2 columns]

# %% [markdown]
# ## Market Basket Analysis
# http://csci.viu.ca/~barskym/teaching/DM2012/labs/LAB7/PartII.html

# %%
df = pd.read_csv('marketbasket.csv')
apriori(df, min_support=0.05, use_colnames=True).sort_values('support', ascending=False)
# Out:
#      support                       itemsets
# 19  0.122704                        [ Eggs]
# 20  0.119030                 [ White Bread]
# 16  0.109478                  [ 2pct. Milk]
# 4   0.097722                [ Potato Chips]
# 1   0.093314   [ 98pct. Fat Free Hamburger]
# 11  0.092579                    [ Hot Dogs]
# 36  0.085231                [ Sweet Relish]
# 3   0.080088                      [ Onions]
# 28  0.079353                  [ Toothpaste]
# 21  0.077884                        [ Cola]
# 35  0.077149                 [ Wheat Bread]
# 37  0.074210                [ Toilet Paper]
# 30  0.071271              [ Hamburger Buns]
# 10  0.069067    [ Pepperoni Pizza - Frozen]
# 33  0.067597               [ Domestic Beer]
# 18  0.066128                    [ Tomatoes]
# 15  0.064658                     [ Bologna]
# 17  0.063924                [ Popcorn Salt]
# 32  0.062454               [ Ramen Noodles]
# 13  0.060985                     [ Raisins]
# 23  0.059515                     [ Bananas]
# 31  0.058780                [ French Fries]
# 26  0.058780                [ Hot Dog Buns]
# 0   0.058780            [ Hair Conditioner]
# 14  0.057311                 [ Pancake Mix]
# 34  0.057311                      [ Garlic]
# 8   0.056576                [ Orange Juice]
# 27  0.055841                     [ Oranges]
# 6   0.055841                       [ Plums]
# 12  0.055841               [ Frozen Shrimp]
# 41  0.055107          [ Eggs,  White Bread]
# 2   0.055107               [ Sugar Cookies]
# 24  0.054372               [ Sandwich Bags]
# 29  0.054372                 [ Canned Tuna]
# 7   0.054372                   [ Mushrooms]
# 22  0.053637                      [ Apples]
# 25  0.052902            [ C Cell Batteries]
# 39  0.052168           [ 2pct. Milk,  Eggs]
# 5   0.051433                     [ Waffles]
# 38  0.051433  [ Potato Chips,  White Bread]
# 40  0.051433    [ 2pct. Milk,  White Bread]
# 9   0.050698                  [ Sour Cream]
